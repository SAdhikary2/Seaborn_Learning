# %% [markdown]
# # Seaborn - GFG

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def_data=sns.load_dataset("iris")

# %%
def_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.lineplot(x="sepal_length",y="sepal_width",data=data)

plt.title('Title using Matplotlib Function')

plt.xlim(5) #setting the x limit of the plot

#Fives types of themes available in seaborn
# sns.set_style("darkgrid")
# sns.set_style("dark")
# sns.set_style("whitegrid")
# sns.set_style("white")
sns.set_style("ticks")

plt.show()

# %%
sns.lineplot(x="sepal_length",y="sepal_width",data=data)

plt.title('Title using Matplotlib Function')

plt.xlim(5) 

sns.despine()#Spines are the lines noting the data boundaries and connecting the axis tick marks. 
#It can be removed using the despine() method.

 

sns.set_style("ticks")

plt.show()

# %%
#Changing the figure size
plt.figure(figsize=(2,4))

sns.lineplot(x="sepal_length",y="sepal_width",data=data)

plt.title('Title using Matplotlib Function')

plt.xlim(5) 

sns.set_style("ticks")

plt.show()

# %%
# Scalling the plots

sns.lineplot(x="sepal_length",y="sepal_width",data=data)

plt.title('Title using Matplotlib Function')

plt.xlim(5) 

sns.set_style("ticks")

#Scalling the plot
#It can be done using the set_context() method. 
#It allows us to override default parameters. 
#This affects things like the size of the labels, lines, and other elements of the plot, but not the overall style. 
#The base context is “notebook”, and the other contexts are “paper”, “talk”, and “poster”.
#font_scale sets the font size.

sns.set_context("talk")

plt.show()

# %%
#setting the style temporarily


def plot():
    sns.lineplot(x="sepal_length",y="sepal_width",data=data)
    
with sns.axes_style('darkgrid'):
    
    #Adding the subplot
    plt.subplot(211)
    plot()

plt.subplot(212)
plot()

# %%
# Color Palette

palette=sns.color_palette()

sns.palplot(palette)

plt.show()

# %%
palette=sns.color_palette('PiYG',11)

sns.palplot(palette)

plt.show()

# %%
palette=sns.color_palette('Greens',11)

sns.palplot(palette)

plt.show()

# %%
#setting the default color palette


def plot():
    
    sns.lineplot(x="sepal_length", y="sepal_width",data=data)
    
sns.set_palette('vlag')
plt.subplot(211)
plot()

sns.set_palette('Accent')
plt.subplot(212)
plot()

plt.show()

# %%
# Multiple plot with the seaborn

def graph():
    sns.lineplot(x="sepal_length", y="sepal_width",data=data)
    
# creating a new figure with width=5 inches
# and height =4 inches
fig= plt.figure(figsize=(5,4))

#Creating first axes for the figure
ax1=fig.add_axes([0.1,0.1,0.8,0.8])

#Plotting the graph
graph()

# Creating second axes for the figure
ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])
 
# plotting the graph
graph()



plt.show()

# %%
# Example2 - Multiple plot with the subplot method

def graph():
    sns.lineplot(x="sepal_length", y="sepal_width",data=data)
    
plt.subplot(121)
graph()

plt.subplot(122)
graph()

plt.show()

# %%
#Example3 - Multiple plot using subplot2grid() method

def graph():
    sns.lineplot(x="sepal_length", y="sepal_width",data=data)
    
#Adding the subplots

axes1=plt.subplot2grid(
(7,1),(0,0),rowspan=2,colspan=1)
graph()

axes2=plt.subplot2grid(
(7,1),(2,0),rowspan=2,colspan=1)
graph()

axes3=plt.subplot2grid(
(7,1),(4,0),rowspan=2,colspan=1)
graph()

# %%
# Multiple plot using the FacetGrid() Method


plot=sns.FacetGrid(data,col="species")

plot.map(plt.plot,"sepal_width")

plt.show()

# %%
#Multiple plot using the PairGrid() method

data=sns.load_dataset("flights")

plot=sns.PairGrid(data)
plot.map(plt.plot)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\New folder\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\New folder\Lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\New folder\Lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %% [markdown]
# # Creating Different Types of Plot

# %%
#Scatter plot

data=sns.load_dataset("iris")

sns.scatterplot(x='sepal_length',y='sepal_width',data=data)

plt.show()

# %%
# box plot

sns.boxplot(x='species',y='sepal_width',data=data)
plt.show()

# %%
#Violinplot

sns.violinplot(x='species',y='sepal_width',data=data)
plt.show()

# %%
# Stripplot

sns.stripplot(x='species',y='sepal_width',data=data)
plt.show()

# %%
#Swarmplot
#Swarmplot is very similar to the stripplot except the fact that the points are adjusted so that they do not overlap


sns.swarmplot(x='species',y='sepal_width',data=data)
plt.show()

# %%
#Factorplot

sns.factorplot(x='species',y='sepal_width',data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 3
#       1 #Factorplot
# ----> 3 sns.factorplot(x='species',y='sepal_width',data=data)
#       4 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'
